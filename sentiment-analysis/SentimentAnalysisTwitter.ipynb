# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json

from nltk.sentiment.util import demo_liu_hu_lexicon


#consumer key, consumer secret, access token, access secret.
ckey="zD5nLXaLzYmp4IUDiI8rdM7by"
csecret="hJmVNtViHRXxmLeERO9dww9zlGct6a1DjznMhBLbuOY9BV6JYQ"
atoken="837081907099811840-JiRiAbpBMQHMtrrwczfGBqzutYjbCPL"
asecret="CXXobZSKEz02osSVaodVEmmuI3Iq6dHQbU6Q8x0Yzsq5h"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        
        username = all_data["user"]["screen_name"]
        sentiment = demo_liu_hu_lexicon(tweet)
        
        print(tweet, sentiment)
        
        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["amazon", "comcast"])
# Out:
# Neutral
# RT @rotzemardini: #Desenlace  #trilogíaCavielli
# EL OCASO DE CAVIELLI disponible el 15 de abril en @amazon
# #Suspense #Romance…  None
# Negative
# RT @W_Alhusseini: Une trahison française - Les collaborationnistes de l'islam radical devoilés,disponible en librairie ou sur amazon:…  None
# Neutral
# Got my Amazon shipment, including DEET for my Vietnam trip (@ Don's Hideaway in Cambridge, Massachusetts) https://t.co/tsBBxAbCB1 None
# Neutral
# 最近読んだ本。
# 面白かった。子育てに良い。子供いないけど。www
# amazonにリンク貼るのが難しいので書名だけ。
#
# パフォーマンス・マネジメント―問題解決のための行動分析学 None
# Neutral
# RT @NatureCutsTags: Lantern Confetti... https://t.co/QjOr6BrFFD via @amazon #naturecuts #confetti #cutouts #decoration #partydecor #vintage… None
# Positive
# RT @reginabaker So excited to be on this tweetchat with @efiajae Amazon #1 Best Selling Author! Congratulations!!  #frameyourday None
# Neutral
# Bug Out Boat Survival: The Post Apocalyptic Survival Trailer Pod (Aftermath S... https://t.co/AA6wS8ZMRm via @amazon #prepper #griddown None
# Neutral
# 📷 thebookboyfriendharem: First Appearance Amazon Link: https://t.co/G5lodzsQRE https://t.co/nNTrYjp2MN None
# Neutral
# https://t.co/H07epsKuNR https://t.co/5kvNJ8ctrC None
# Neutral
# Amazon Refunding up to $70M for Kids' In-App Purchases https://t.co/q2esT9a0QK #news None
# Positive
# I just participated in an #AmazonGiveaway for Stand Up Desk Height Adjustable - New.... Check it out here:
#  https://t.co/FbDFCVtOJS None
# Neutral
# 装甲悪鬼村正 三世村正 (1/7スケール PVC塗装済み完成品)https://t.co/zDnUru193v None
# Neutral
# 懸賞情報もたくさんあり
# お小遣い稼ぎができる
# お得生活応援サイト☆
# 「チャンスイット」
#
# 貯めたポイントは現金や
# Amazonギフト券
# iTunesコードなどに
# 交換できるよ♪
# RT @TOVILLAMA: ESA shows 30 years of deforestation in Amazon rainforest https://t.co/UXRooi8Z54 None
# Positive
# might just need to make my peace with not watching Sagrada Reset and Anonymous Noise this season. Pls have mercy amazon None
# Neutral
# 50 COLORS!
# https://t.co/N73HrfLnIX
# #Celtics #defendtheland #NationalWalkingDay #WITW #COYS #nba #mlb Dustin Johnson 1rrrrrriirirrjrhrhrbrbrr None
# Neutral
# RT @NatureCutsTags: Sun Gift Tags... https://t.co/XP6SFodXaG via @amazon #naturecuts #nature #sun #sunshine #weather #beach #oceantheme #ru… None
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     231             try:
# --> 232                 yield
#     233
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     313                 cache_content = False
# --> 314                 data = self._fp.read(amt)
#     315                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# C:\Program Files\Anaconda3\lib\http\client.py in read(self, amt)
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#
# C:\Program Files\Anaconda3\lib\http\client.py in readinto(self, b)
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#
# C:\Program Files\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#
# C:\Program Files\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     538                 # We are at the end of chunk. dicard chunk end
# --> 539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
#
# C:\Program Files\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#
# C:\Program Files\Anaconda3\lib\socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# C:\Program Files\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#
# C:\Program Files\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#
# C:\Program Files\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-8-4f8cdaf3fe01> in <module>()
#      35
#      36 twitterStream = Stream(auth, listener())
# ---> 37 twitterStream.filter(track=["amazon", "comcast"])
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\Program Files\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     322                     # no harm in redundantly calling close.
#     323                     self._fp.close()
# --> 324                     flush_decoder = True
#     325
#     326         if data:
#
# C:\Program Files\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     248             except (HTTPException, SocketError) as e:
#     249                 # This includes IncompleteRead.
# --> 250                 raise ProtocolError('Connection broken: %r' % e, e)
#     251
#     252             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
